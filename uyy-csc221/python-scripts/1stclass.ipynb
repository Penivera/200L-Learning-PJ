# %%
'''from math import sqrt


T1 = 150
P1 = 260
T2 = 193.5 
V1 = 27.9
P2 = 345.1
V2 = 38.1


n = sqrt((P2 * V2 * T2) / (P1 * V1 * T1))
print("n = " + str(n))'''
yob = int(input("Enter your year of birth: "))

age = 2025 -yob 
print("You are " + str(age) + " years old")

print("Welcome to python")
name = "Peniel Ben"
reg_no = "22/SC/CO/1181"
department = "Computer Science"
lecture = "UYY-CSC211"
phone = "+2348078617821"
level = "200 Level"
header1 = "Name"
header2 = "Reg no."
header3 = "Department"
header4 = "Lecture"
header5 = "Phone"
header6 = "Level"
print(header1 + '\t\t' + header2 + '\t\t' + header3 + '\t\t' + header4 + '\t\t' + header5 + '\t\t' + header6)
print(name + '\t'+ reg_no +'\t'+ department + '\t'+ lecture + '\t'+ phone +'\t'+ level +'\n')
# Out:
# You are 19 years old
# Welcome to python
# Name		Reg no.		Department		Lecture		Phone		Level
# Peniel Ben	22/SC/CO/1181	Computer Science	UYY-CSC211	+2348078617821	200 Level
